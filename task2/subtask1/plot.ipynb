# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([2, 4, 6, 8, 16, 20, 40])
y2 = np.array([1.9278482, 4.3068418, 5.4231186, 7.3948585, 11.1406205, 11.6609230, 15.0342269])
y4 = np.array([1.9809000, 4.2382540, 5.9520148, 7.1950520, 12.8885523, 15.4545767, 16.8520469])

x_line = np.array([0, 40])

plt.plot(x, y2, 'red', label='M = 20 000')
plt.plot(x, y4, 'green', label='M = 40 000')
plt.plot(x_line, x_line, 'b--', label='y = x')
plt.xlabel('p')
plt.ylabel('Sp')
plt.legend()
plt.grid(True)
plt.show()
