# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([2, 4, 6, 8, 16, 20, 40])
y2 = np.array([1.8972488, 4.1710755, 4.8338258, 6.2902800, 11.6326217, 13.2446218, 11.7405334])
y4 = np.array([2.1536959, 4.0401019, 5.9861087, 7.4450362, 12.2905123, 15.4651096, 16.2448888])

x_line = np.array([0, 40])

plt.plot(x, y2, 'red', label='M = 20 000')
plt.plot(x, y4, 'green', label='M = 40 000')
plt.plot(x_line, x_line, 'b--', label='y = x')
plt.xlabel('p')
plt.ylabel('Sp')
plt.legend()
plt.grid(True)
plt.show()
