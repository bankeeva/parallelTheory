# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([2, 4, 7, 8, 16, 20, 40])
y = np.array([1.7480919, 3.6929079, 6.3284387, 7.1771004, 13.2882781, 16.3100538, 21.0658280])
x_line = np.array([0, 40])

plt.plot(x, y, 'red', label='nsteps = 40 000 000')
plt.plot(x_line, x_line, 'b--', label='y = x')
plt.xlabel('p')
plt.ylabel('Sp')
plt.legend()
plt.grid(True)
plt.show()
